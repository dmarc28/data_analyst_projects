# %%
import sqlite3
import pandas as pd
import matplotlib as plt

# %%
conn = sqlite3.connect('raihan_chicago_311_2018.db')
c = conn.cursor()

# %%
# load the data into a Pandas DataFrame
# chicago_311_2018 = pd.read_csv('./raihan_chicago_311_2018.csv')
# write the data to a sqlite table
# chicago_311_2018 = chicago_311_2018.to_sql('chicago_311_2018', conn, if_exists='append', index = False)

# %% [markdown]
# ### 1. Retrieve the total number of complaints for each category.

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''
            SELECT category as Complaint_category
            ,COUNT(category) as Counts
            ,Rank() over (ORDER BY COUNT(category) DESC) AS Rank
            FROM chicago_311_2018
            GROUP BY category
            ORDER BY 2 DESC
            LIMIT 10
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                       Complaint_category  Counts  Rank
# 0               Graffiti Removal Request   26154     1
# 1                   Weed Removal Request   22147     2
# 2             Street Light Out Complaint   21521     3
# 3           Rodent Baiting/Rat Complaint   12360     4
# 4               Garbage Cart Maintenance   12278     5
# 5                      Tree Trim Request   11346     6
# 6            Pothole in Street Complaint   10172     7
# 7  Sign Repair Request - All Other Signs    9150     8
# 8              311 INFORMATION ONLY CALL    8534     9
# 9            Abandoned Vehicle Complaint    6906    10

# %% [markdown]
# ### 2. Calculate the average resolution time (in days) for closed complaints..

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''
            with cte as 
                (SELECT request_id
                ,responsibleagency
                ,closed_date,created_date
                ,CAST(julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) AS INTEGER) AS days_taken
                FROM chicago_311_2018
                WHERE closed_date is NOT NULL and created_date IS NOT NULL
                )
            SELECT responsibleagency as Responsible_agency
            ,MAX(days_taken) as Days_taken_max
            From cte
            GROUP BY responsibleagency
            ORDER BY MAX(days_taken) DESC;
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                                  Responsible_agency  Days_taken_max
# 0                            Streets and Sanitation             657
# 1              DWM - Department of Water Management             655
# 2               CDOT - Department of Transportation             645
# 3   BACP - Business Affairs and Consumer Protection             592
# 4                                   DOB - Buildings             518
# 5                           Animal Care and Control             206
# 6                               City Clerk's Office             138
# 7                                            Health              96
# 8            Department of Planning and Development              20
# 9                      Extreme Weather Notification               0
# 10                                         Aviation               0
# 11                                311 City Services               0

# %% [markdown]
# ### 3. Show a table with responsible agency, maximum days taken, and case ID that has taken the highest time to solve

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''         
            with cte as 
                (SELECT 
                request_id
                ,responsibleagency
                ,closed_date,created_date
                ,CAST(julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) AS INTEGER) AS days_taken
                FROM chicago_311_2018
                WHERE closed_date is NOT NULL and created_date IS NOT NULL
                )
            SELECT 
            cte.responsibleagency AS Agency
            ,MAX(days_taken) AS Days_taken_max 
            ,cte.request_id AS Request
            From cte
            Join (
                SELECT 
                DISTINCT(cte.responsibleagency)
                ,MAX(days_taken) as max_taken FROM cte GROUP BY responsibleagency)as cte_2 
            ON cte.responsibleagency = cte_2.responsibleagency 
            AND cte.days_taken = cte_2.max_taken
            GROUP BY cte.responsibleagency
            ORDER BY 2 DESC
            ;
            
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                                              Agency  Days_taken_max  \
# 0                            Streets and Sanitation             657
# 1              DWM - Department of Water Management             655
# 2               CDOT - Department of Transportation             645
# 3   BACP - Business Affairs and Consumer Protection             592
# 4                                   DOB - Buildings             518
# 5                           Animal Care and Control             206
# 6                               City Clerk's Office             138
# 7                                            Health              96
# 8            Department of Planning and Development              20
# 9                      Extreme Weather Notification               0
# 10                                         Aviation               0
# 11                                311 City Services               0
#
#           Request
# 0   SR18-00084296
# 1   SR18-00085058
# 2   SR18-00083485
# 3   SR18-00105990
# 4   SR18-00142045
# 5   SR18-00142477
# 6   SR18-00237885
# 7   SR19-00626132
# 8   SR18-00194875
# 9   SR18-00222661
# 10  SR18-00194556
# 11  SR18-00242740

# %% [markdown]
# ### 4. List the boroughs with the highest number of complaints.

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''         

            WITH cte AS
                (SELECT 
                    precinct AS Precinct
                    ,count(request_id) AS Request_counts
                
                FROM chicago_311_2018
                Group BY precinct
                ORDER BY 2 DESC
                LIMIT 10)
            SELECT *
            FROM cte;
            
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#    Precinct  Request_counts
# 0      46.0           10233
# 1      10.0            6379
# 2      11.0            6095
# 3      15.0            6000
# 4      19.0            5891
# 5       5.0            5876
# 6      17.0            5833
# 7       2.0            5678
# 8       3.0            5658
# 9       6.0            5644

# %% [markdown]
# ### 5. Create a table showing agency name, maximum days taken to complete a request and the category name of that request

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''         
            with cte as 
                (SELECT 
                category
                ,responsibleagency
                ,closed_date,created_date
                ,CAST(julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) AS INTEGER) AS days_taken
                FROM chicago_311_2018
                WHERE closed_date is NOT NULL and created_date IS NOT NULL
                )
            SELECT 
            cte.responsibleagency AS Agency
            ,MAX(days_taken) AS Days_taken_max
            ,cte.category AS Category
            From cte
            Join (
                SELECT 
                DISTINCT cte.responsibleagency AS Agency
                ,MAX(days_taken) as Days_taken_max
            FROM cte 
            GROUP BY responsibleagency)as cte_2 
            ON cte.responsibleagency = cte_2.Agency 
            AND cte.days_taken = cte_2.Days_taken_max
            GROUP BY cte_2.Agency
            ORDER BY 2 DESC
            ;
            
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                                              Agency  Days_taken_max  \
# 0                            Streets and Sanitation             657
# 1              DWM - Department of Water Management             655
# 2               CDOT - Department of Transportation             645
# 3   BACP - Business Affairs and Consumer Protection             592
# 4                                   DOB - Buildings             518
# 5                           Animal Care and Control             206
# 6                               City Clerk's Office             138
# 7                                            Health              96
# 8            Department of Planning and Development              20
# 9                      Extreme Weather Notification               0
# 10                                         Aviation               0
# 11                                311 City Services               0
#
#                                        Category
# 0                         Tree Planting Request
# 1             Sewer Cleaning Inspection Request
# 2                     Alley Light Out Complaint
# 3                                  Cab Feedback
# 4           Vacant/Abandoned Building Complaint
# 5                        Stray Animal Complaint
# 6                City Vehicle Sticker Violation
# 7                          Restaurant Complaint
# 8   Bungalow Rehab/Purchase Information Request
# 9                  Extreme Weather Notification
# 10                     Aircraft Noise Complaint
# 11                    311 INFORMATION ONLY CALL

# %% [markdown]
# ### 6. List the boroughs with the lowest number of complaints.

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''         

            SELECT 
                precinct,
                count(request_id)
            FROM chicago_311_2018
            Group BY precinct
            ORDER BY 2 ASC
            LIMIT 10;
            
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#    precinct  count(request_id)
# 0      57.0                 79
# 1      55.0                178
# 2      56.0                182
# 3      54.0                216
# 4      52.0                408
# 5      51.0                439
# 6      53.0                530
# 7      50.0                575
# 8      49.0               1066
# 9      48.0               1197

# %% [markdown]
# ### 7. Determine the agencies with the highest number of complaints and their corresponding complaint types.

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''
            SELECT 
                responsibleagency as agency,
                COUNT(request_id) as total_comp_for_agency
                ,MAX(category) as max_comp_categor
            FROM chicago_311_2018
            GROUP BY responsibleagency
            ORDER BY 2 DESC
            ;

''')

# Fetch all the results
results = c.fetchall()

# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                                              agency  total_comp_for_agency  \
# 0                            Streets and Sanitation                 120430
# 1               CDOT - Department of Transportation                  65070
# 2              DWM - Department of Water Management                  11454
# 3                                   DOB - Buildings                   9434
# 4                           Animal Care and Control                   8917
# 5                                 311 City Services                   8534
# 6   BACP - Business Affairs and Consumer Protection                   3021
# 7                                          Aviation                   1807
# 8                                            Health                    903
# 9            Department of Planning and Development                    343
# 10                                             Fire                     71
# 11                              City Clerk's Office                     15
# 12                     Extreme Weather Notification                      1
#
#                                max_comp_categor
# 0                    Yard Waste Pick-Up Request
# 1                   Viaduct Light Out Complaint
# 2                   Water in Basement Complaint
# 3           Vacant/Abandoned Building Complaint
# 4                      Vicious Animal Complaint
# 5                     311 INFORMATION ONLY CALL
# 6            Tobacco - Sale to Minors Complaint
# 7                      Aircraft Noise Complaint
# 8   Smokeless Tobacco at Sports Event Complaint
# 9               Home Buyer Program Info Request
# 10               Fire Safety Inspection Request
# 11               City Vehicle Sticker Violation
# 12                 Extreme Weather Notification

# %% [markdown]
# ### 8. provide a table displaying the Ward, the total number of complaints, the category with the highest number of complaints, and the category with the lowest number of complaints?

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''
            SELECT 
                ward_id as Ward
                ,COUNT(request_id) as Total_complaints
                ,MAX(category) as max_comp_categ
                ,MIN(category) as least_comp_categ
                FROM chicago_311_2018
                GROUP BY ward_id
                ORDER BY 2 DESC
            ;

''')

# Fetch all the results
results = c.fetchall()

# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#     Ward  Total_complaints              max_comp_categ  \
# 0   28.0             15030  Yard Waste Pick-Up Request
# 1   34.0              8805  Yard Waste Pick-Up Request
# 2   24.0              6882  Yard Waste Pick-Up Request
# 3    9.0              6736  Yard Waste Pick-Up Request
# 4   27.0              6668  Yard Waste Pick-Up Request
# 5    8.0              5843  Yard Waste Pick-Up Request
# 6   47.0              5448  Yard Waste Pick-Up Request
# 7   12.0              5410  Yard Waste Pick-Up Request
# 8   16.0              5386  Yard Waste Pick-Up Request
# 9   21.0              5340  Yard Waste Pick-Up Request
# 10  45.0              5273  Yard Waste Pick-Up Request
# 11  20.0              5217  Yard Waste Pick-Up Request
# 12  32.0              5164  Yard Waste Pick-Up Request
# 13  14.0              5149  Yard Waste Pick-Up Request
# 14   6.0              5010  Yard Waste Pick-Up Request
# 15   1.0              4879  Yard Waste Pick-Up Request
# 16  39.0              4829  Yard Waste Pick-Up Request
# 17  19.0              4800  Yard Waste Pick-Up Request
# 18  18.0              4767  Yard Waste Pick-Up Request
# 19  17.0              4721  Yard Waste Pick-Up Request
# 20  25.0              4703  Yard Waste Pick-Up Request
# 21  41.0              4653  Yard Waste Pick-Up Request
# 22  10.0              4609  Yard Waste Pick-Up Request
# 23   7.0              4472  Yard Waste Pick-Up Request
# 24  37.0              4459  Yard Waste Pick-Up Request
# 25  38.0              4416  Yard Waste Pick-Up Request
# 26  13.0              4332  Yard Waste Pick-Up Request
# 27  11.0              4244  Yard Waste Pick-Up Request
# 28   3.0              4075  Yard Waste Pick-Up Request
# 29  15.0              4068  Yard Waste Pick-Up Request
# 30  33.0              4002  Yard Waste Pick-Up Request
# 31  22.0              3995  Yard Waste Pick-Up Request
# 32  29.0              3817  Yard Waste Pick-Up Request
# 33   4.0              3775  Yard Waste Pick-Up Request
# 34  42.0              3750  Yard Waste Pick-Up Request
# 35  23.0              3641  Yard Waste Pick-Up Request
# 36  30.0              3522  Yard Waste Pick-Up Request
# 37  36.0              3445  Yard Waste Pick-Up Request
# 38  35.0              3420  Yard Waste Pick-Up Request
# 39  40.0              3412  Yard Waste Pick-Up Request
# 40  26.0              3237  Yard Waste Pick-Up Request
# 41  31.0              3015  Yard Waste Pick-Up Request
# 42  50.0              2966  Yard Waste Pick-Up Request
# 43   5.0              2806  Yard Waste Pick-Up Request
# 44   2.0              2677  Yard Waste Pick-Up Request
# 45  44.0              2586  Yard Waste Pick-Up Request
# 46  43.0              2542  Yard Waste Pick-Up Request
# 47  49.0              2257  Yard Waste Pick-Up Request
# 48  48.0              2158  Yard Waste Pick-Up Request
# 49   NaN              1808  Yard Waste Pick-Up Request
# 50  46.0              1781  Yard Waste Pick-Up Request
#
#                least_comp_categ
# 0     311 INFORMATION ONLY CALL
# 1   Abandoned Vehicle Complaint
# 2   Abandoned Vehicle Complaint
# 3   Abandoned Vehicle Complaint
# 4     311 INFORMATION ONLY CALL
# 5   Abandoned Vehicle Complaint
# 6     311 INFORMATION ONLY CALL
# 7   Abandoned Vehicle Complaint
# 8   Abandoned Vehicle Complaint
# 9     311 INFORMATION ONLY CALL
# 10  Abandoned Vehicle Complaint
# 11  Abandoned Vehicle Complaint
# 12  Abandoned Vehicle Complaint
# 13  Abandoned Vehicle Complaint
# 14  Abandoned Vehicle Complaint
# 15  Abandoned Vehicle Complaint
# 16  Abandoned Vehicle Complaint
# 17  Abandoned Vehicle Complaint
# 18    311 INFORMATION ONLY CALL
# 19  Abandoned Vehicle Complaint
# 20  Abandoned Vehicle Complaint
# 21  Abandoned Vehicle Complaint
# 22  Abandoned Vehicle Complaint
# 23  Abandoned Vehicle Complaint
# 24    311 INFORMATION ONLY CALL
# 25  Abandoned Vehicle Complaint
# 26  Abandoned Vehicle Complaint
# 27  Abandoned Vehicle Complaint
# 28  Abandoned Vehicle Complaint
# 29  Abandoned Vehicle Complaint
# 30  Abandoned Vehicle Complaint
# 31  Abandoned Vehicle Complaint
# 32  Abandoned Vehicle Complaint
# 33  Abandoned Vehicle Complaint
# 34  Abandoned Vehicle Complaint
# 35    311 INFORMATION ONLY CALL
# 36  Abandoned Vehicle Complaint
# 37  Abandoned Vehicle Complaint
# 38  Abandoned Vehicle Complaint
# 39  Abandoned Vehicle Complaint
# 40  Abandoned Vehicle Complaint
# 41  Abandoned Vehicle Complaint
# 42    311 INFORMATION ONLY CALL
# 43  Abandoned Vehicle Complaint
# 44    311 INFORMATION ONLY CALL
# 45  Abandoned Vehicle Complaint
# 46  Abandoned Vehicle Complaint
# 47    311 INFORMATION ONLY CALL
# 48  Abandoned Vehicle Complaint
# 49  Abandoned Vehicle Complaint
# 50  Abandoned Vehicle Complaint

# %% [markdown]
# ### 9. Fetch a table showing daily average complaints and daily maximum complaints received by each agency

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''
            WITH cte as
            (SELECT 
                responsibleagency as Agency
                ,COUNT(request_id) as Total_complaints
                ,CAST(julianday(substr(created_date, 1, 10)) AS date) as day
            FROM chicago_311_2018
            GROUP BY 1, 3)
            
            SELECT
                Agency
                , ROUND(AVG(Total_complaints)) as daily_avg_compl
                , MAX(Total_complaints) as daily_max_com
            FROM cte
            GROUP BY 1
            ORDER By 2 DESC
            ;

''')

# Fetch all the results
results = c.fetchall()

# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                                              Agency  daily_avg_compl  \
# 0                            Streets and Sanitation            655.0
# 1                                 311 City Services            610.0
# 2               CDOT - Department of Transportation            354.0
# 3                                          Aviation            129.0
# 4              DWM - Department of Water Management             62.0
# 5                                   DOB - Buildings             51.0
# 6                           Animal Care and Control             49.0
# 7   BACP - Business Affairs and Consumer Protection             17.0
# 8                                            Health              5.0
# 9            Department of Planning and Development              3.0
# 10                              City Clerk's Office              2.0
# 11                                             Fire              1.0
# 12                     Extreme Weather Notification              1.0
#
#     daily_max_com
# 0            2097
# 1            1120
# 2             815
# 3             318
# 4             305
# 5             126
# 6             126
# 7              46
# 8              14
# 9               8
# 10              6
# 11              4
# 12              1

# %% [markdown]
# ### 10. Create a table that presents the total number of complaints handled by each agency, along with the average time taken to address each complaint.

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''
            SELECT 
                 responsibleagency as Agency
                ,COUNT(request_id) as Total_complaints
                ,ROUND(AVG(CAST(julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) AS INTEGER))) AS avg_completion_time_days

            FROM chicago_311_2018
            GROUP by 1
            ORDER BY 2 DESC
            
            ;

''')

# Fetch all the results
results = c.fetchall()

# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#                                              Agency  Total_complaints  \
# 0                            Streets and Sanitation            120430
# 1               CDOT - Department of Transportation             65070
# 2              DWM - Department of Water Management             11454
# 3                                   DOB - Buildings              9434
# 4                           Animal Care and Control              8917
# 5                                 311 City Services              8534
# 6   BACP - Business Affairs and Consumer Protection              3021
# 7                                          Aviation              1807
# 8                                            Health               903
# 9            Department of Planning and Development               343
# 10                                             Fire                71
# 11                              City Clerk's Office                15
# 12                     Extreme Weather Notification                 1
#
#     avg_completion_time_days
# 0                       31.0
# 1                       34.0
# 2                       37.0
# 3                       42.0
# 4                       25.0
# 5                        0.0
# 6                       59.0
# 7                        0.0
# 8                       32.0
# 9                        3.0
# 10                       NaN
# 11                      61.0
# 12                       0.0

# %% [markdown]
# ### 11. Calculate the percentage of complaints closed within 7 days of submission for each borough

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''         

        SELECT ward_id,
               COUNT(CASE WHEN julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) <= 7 THEN 1 END) AS complaints_closed_within_7_days,
               ROUND((COUNT(CASE WHEN julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) <= 7 THEN 1 END) * 100.0 / COUNT(*)),2) AS percentage
               ,Rank() OVER(ORDER BY ROUND((COUNT(CASE WHEN julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) <= 7 THEN 1 END) * 100.0 / COUNT(*)),2) DESC) AS Rank
        FROM chicago_311_2018
        GROUP BY ward_id
        ORDER BY percentage DESC;
            
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#     ward_id  complaints_closed_within_7_days  percentage  Rank
# 0      28.0                            12821       85.30     1
# 1       NaN                             1484       82.08     2
# 2      24.0                             5034       73.15     3
# 3      47.0                             3947       72.45     4
# 4      14.0                             3652       70.93     5
# 5       4.0                             2667       70.65     6
# 6      25.0                             3317       70.53     7
# 7       3.0                             2861       70.21     8
# 8      32.0                             3561       68.96     9
# 9       1.0                             3360       68.87    10
# 10     12.0                             3714       68.65    11
# 11     46.0                             1219       68.44    12
# 12     27.0                             4508       67.61    13
# 13     44.0                             1740       67.29    14
# 14     22.0                             2686       67.23    15
# 15     34.0                             5905       67.06    16
# 16     42.0                             2504       66.77    17
# 17     15.0                             2709       66.59    18
# 18     33.0                             2631       65.74    19
# 19     43.0                             1635       64.32    20
# 20      2.0                             1715       64.06    21
# 21     20.0                             3338       63.98    22
# 22     40.0                             2182       63.95    23
# 23     11.0                             2703       63.69    24
# 24      9.0                             4279       63.52    25
# 25     49.0                             1425       63.14    26
# 26     35.0                             2139       62.54    27
# 27      5.0                             1717       61.19    28
# 28     37.0                             2700       60.55    29
# 29     17.0                             2782       58.93    30
# 30     48.0                             1260       58.39    31
# 31     10.0                             2684       58.23    32
# 32     31.0                             1741       57.74    33
# 33     19.0                             2745       57.19    34
# 34     23.0                             2082       57.18    35
# 35     26.0                             1839       56.81    36
# 36     16.0                             3059       56.80    37
# 37     13.0                             2447       56.49    38
# 38     30.0                             1984       56.33    39
# 39     50.0                             1667       56.20    40
# 40     39.0                             2704       56.00    41
# 41     45.0                             2930       55.57    42
# 42     36.0                             1877       54.48    43
# 43      7.0                             2436       54.47    44
# 44      8.0                             3177       54.37    45
# 45     29.0                             2075       54.36    46
# 46     21.0                             2820       52.81    47
# 47     38.0                             2321       52.56    48
# 48      6.0                             2593       51.76    49
# 49     18.0                             2454       51.48    50
# 50     41.0                             2373       51.00    51

# %% [markdown]
# ### 12. Find the week with the highest number of complaints and the week with the lowest number of complaints.

# %%
c = conn.cursor()

# Execute the SQL query
c.execute('''         

        SELECT ward_id,
               COUNT(CASE WHEN julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) <= 7 THEN 1 END) AS complaints_closed_within_7_days,
               ROUND((COUNT(CASE WHEN julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) <= 7 THEN 1 END) * 100.0 / COUNT(*)),2) AS percentage
               ,Rank() OVER(ORDER BY ROUND((COUNT(CASE WHEN julianday(substr(closed_date, 1, 10)) - julianday(substr(created_date, 1, 10)) <= 7 THEN 1 END) * 100.0 / COUNT(*)),2) DESC) AS Rank
        FROM chicago_311_2018
        GROUP BY ward_id
        ORDER BY percentage DESC;
            
          ''')

# Fetch all the results
results = c.fetchall()
# Convert the results to a DataFrame
df = pd.DataFrame(results, columns=[desc[0] for desc in c.description])

# Display the DataFrame as a table
df
# Out:
#     ward_id  complaints_closed_within_7_days  percentage  Rank
# 0      28.0                            12821       85.30     1
# 1       NaN                             1484       82.08     2
# 2      24.0                             5034       73.15     3
# 3      47.0                             3947       72.45     4
# 4      14.0                             3652       70.93     5
# 5       4.0                             2667       70.65     6
# 6      25.0                             3317       70.53     7
# 7       3.0                             2861       70.21     8
# 8      32.0                             3561       68.96     9
# 9       1.0                             3360       68.87    10
# 10     12.0                             3714       68.65    11
# 11     46.0                             1219       68.44    12
# 12     27.0                             4508       67.61    13
# 13     44.0                             1740       67.29    14
# 14     22.0                             2686       67.23    15
# 15     34.0                             5905       67.06    16
# 16     42.0                             2504       66.77    17
# 17     15.0                             2709       66.59    18
# 18     33.0                             2631       65.74    19
# 19     43.0                             1635       64.32    20
# 20      2.0                             1715       64.06    21
# 21     20.0                             3338       63.98    22
# 22     40.0                             2182       63.95    23
# 23     11.0                             2703       63.69    24
# 24      9.0                             4279       63.52    25
# 25     49.0                             1425       63.14    26
# 26     35.0                             2139       62.54    27
# 27      5.0                             1717       61.19    28
# 28     37.0                             2700       60.55    29
# 29     17.0                             2782       58.93    30
# 30     48.0                             1260       58.39    31
# 31     10.0                             2684       58.23    32
# 32     31.0                             1741       57.74    33
# 33     19.0                             2745       57.19    34
# 34     23.0                             2082       57.18    35
# 35     26.0                             1839       56.81    36
# 36     16.0                             3059       56.80    37
# 37     13.0                             2447       56.49    38
# 38     30.0                             1984       56.33    39
# 39     50.0                             1667       56.20    40
# 40     39.0                             2704       56.00    41
# 41     45.0                             2930       55.57    42
# 42     36.0                             1877       54.48    43
# 43      7.0                             2436       54.47    44
# 44      8.0                             3177       54.37    45
# 45     29.0                             2075       54.36    46
# 46     21.0                             2820       52.81    47
# 47     38.0                             2321       52.56    48
# 48      6.0                             2593       51.76    49
# 49     18.0                             2454       51.48    50
# 50     41.0                             2373       51.00    51
